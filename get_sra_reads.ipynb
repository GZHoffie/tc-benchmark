# %%
from pysradb import SRAweb

# We collect reads from the following study
"""
Study: Genome sequencing and hybrid assembly of microbial isolates derived from the human gut.
PRJNA885826 • SRP438478
Abstract: We generated a collection of complete or near complete genomes of microbial isolates 
derived from the human gut using a combination of Illumina paired end reads and Oxford nanopore long reads.
"""

db = SRAweb()
study_df = db.sra_metadata("SRP438478", detailed=True)

# %%
study_df = study_df[study_df["instrument_model_desc"] == "OXFORD_NANOPORE"]
study_df.head()
# Out:
#   study_accession                                        study_title  \
# 1       SRP438478  Genome sequencing and hybrid assembly of micro...
# 3       SRP438478  Genome sequencing and hybrid assembly of micro...
# 5       SRP438478  Genome sequencing and hybrid assembly of micro...
# 6       SRP438478  Genome sequencing and hybrid assembly of micro...
# 8       SRP438478  Genome sequencing and hybrid assembly of micro...
#
#   experiment_accession                                   experiment_title  \
# 1          SRX20431359  PCR free Oxford Nanopore sequencing of genomic...
# 3          SRX20431357  PCR free Oxford Nanopore sequencing of genomic...
# 5          SRX20431355  PCR free Oxford Nanopore sequencing of genomic...
# 6          SRX20431354  PCR free Oxford Nanopore sequencing of genomic...
# 8          SRX20431352  PCR free Oxford Nanopore sequencing of genomic...
#
#                                      experiment_desc organism_taxid  \
# ...

# %%
study_df.columns
# Out:
# Index(['run_accession', 'study_accession', 'study_title',
#        'experiment_accession', 'experiment_title', 'experiment_desc',
#        'organism_taxid', 'organism_name', 'library_name', 'library_strategy',
#        'library_source', 'library_selection', 'library_layout',
#        'sample_accession', 'sample_title', 'biosample', 'bioproject',
#        'instrument', 'instrument_model', 'instrument_model_desc',
#        'total_spots', 'total_size', 'run_total_spots', 'run_total_bases',
#        'run_alias', 'public_filename', 'public_url', 'public_size',
#        'public_date', 'public_md5', 'public_version', 'public_semantic_name',
#        'public_supertype', 'public_sratoolkit', 'ncbi_url', 'ncbi_free_egress',
#        'ncbi_access_type', 'aws_url', 'aws_free_egress', 'aws_access_type',
#        'gcp_url', 'gcp_free_egress', 'gcp_access_type', 'experiment_alias',
#        'strain', 'collection_date', 'env_broad_scale', 'env_local_scale',
# ...

# %%
for accession in study_df["run_accession"]:
    print(accession, end=" ")
# Out:
# SRR24651171 SRR24651172 SRR24651173 SRR24651174 SRR24651175 SRR24651176 SRR24651177 SRR24651178 SRR24651179 SRR24651180 SRR24651181 SRR24651182 SRR24651183 SRR24651184 SRR24651185 SRR24651186 SRR24651187 SRR24651188 SRR24651189 SRR24651190 SRR24651191 SRR24651192 SRR24651193 SRR24651194 SRR24651195 SRR24651196 SRR24651197 SRR24651198 SRR24651199 SRR24651200 SRR24651201 SRR24651202 SRR24651203 SRR24651204 SRR24651205 SRR24651206 SRR24651207 SRR24651208 SRR24651209 SRR24651210 SRR24651211 SRR24651212 SRR24651213 SRR24651214 SRR24651215 SRR24651216 SRR24651217 SRR24651218 SRR24651219 SRR24651220 SRR24651221 SRR24651222 SRR24651223 SRR24651224 SRR24651225 SRR24651226 SRR24651227 SRR24651228 SRR24651229 SRR24651230 SRR24651231 SRR24651232 SRR24651233 SRR24651234 SRR24651235 SRR24651236 SRR24651237 SRR24651238 SRR24651239 SRR24651240 SRR24651241 SRR24651242 SRR24651243 SRR24651244 SRR24651245 SRR24651246 SRR24651247 SRR24651248 SRR24651249 SRR24651250 SRR24651251 SRR24651252 SRR24651253 SR
# ...
